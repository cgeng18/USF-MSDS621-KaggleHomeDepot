# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.feature_extraction import stop_words

from nltk.stem.porter import PorterStemmer
from autocorrect import spell
from scipy import spatial
import operator
import time

# %%
glove_file = '../data/glove.6B/glove.6B.300d.txt'
def make_dictionary(file):
    '''
    Initiate the glove model as a dictionary
    input: A String which is a file in the project directory
    returns: A dictionary with item = word : 300 d list
    '''
    vecs = dict()
    with open(file) as f:
        lines = f.readlines()
        for word_and_vec in lines:
            elems = word_and_vec.strip().split(' ')
            word = elems[0]
            vec = np.array(elems[1:], dtype=float)
            vecs[word] = vec
    return vecs

# %%
glove_dic=make_dictionary(glove_file)

# %%
stops = list(stop_words.ENGLISH_STOP_WORDS)

# %%
products = pd.read_csv('../data/product_descriptions.csv')
train = pd.read_csv('../data/train.csv', encoding='ISO-8859-1')
train = train.set_index('product_uid').join(products.set_index('product_uid'))
train = train.reset_index()

# %%
search_term=train['search_term']

# %%
def clean_term_list(search_terms:list):
    f = open('output.txt', "w")
    f.close()
    for i in range(len(search_terms)):
        t=''
        search_terms[i]=search_terms[i].lower()
        for term in search_terms[i].split(' '):
            if ( term.isalpha() and len(term)>2 and (term not in stops) and (term in glove_dic)):
                t = t +' '+ term
        search_terms[i]=t

        f = open('output.txt', "a")
        f.write(search_terms[i])
        f.write('\n')
        f.close()

# %%
# the following code takes hours....
# you can load the 'output.txt' file to check the result

# clean_term_list(search_term)

# %%
f = open("output.txt","rt") 
clean_terms = f.readlines()
clean_terms = [line.strip() for line in clean_terms]
f.close()

# %%
train['clean_terms']=clean_terms

# %%
cleaned=list(train['clean_terms'])  # without transfering into list, the changes made on cleaned will be made on train!
title=list(train['product_title'])
desc=list(train['product_description'])

# %%
clean_length=np.zeros(len(cleaned))
for i in range(len(cleaned)):
        if not pd.isnull(cleaned[i]):
            clean_length[i]=len(cleaned[i].split(' '))
            
train['clean_length']=clean_length

# %%
title_length=np.zeros(len(title))
for i in range(len(title)):
        title_length[i]=len(title[i].split(' '))
            
train['title_length']=title_length

# %%
desc_length=np.zeros(len(desc))
for i in range(len(desc)):
        desc_length[i]=len(desc[i].split(' '))
            
train['desc_length']=desc_length

# %%
def clean_term_in_doc(terms:list, title:list):
    count=np.zeros(len(terms))
    for i in range(len(terms)):
        if not pd.isnull(terms[i]): 
            title[i]=title[i].lower()
            #print(terms[i])
            for term in terms[i].split(' '):
                #print(term, title[i].split(' '))
                if term in title[i].split(' '):
                    count[i]+=1
    return count

# %%
c_title=clean_term_in_doc(cleaned, title)
c_desc=clean_term_in_doc(cleaned, desc)

# %%
train['clean_terms_in_title']=c_title
train['clean_terms_in_desc']=c_desc

# %%
train
# Out:
#        product_uid      id                                      product_title  \
# 0           100001       2                  Simpson Strong-Tie 12-Gauge Angle
# 1           100001       3                  Simpson Strong-Tie 12-Gauge Angle
# 2           100002       9  BEHR Premium Textured DeckOver 1-gal. #SC-141 ...
# 3           100005      16  Delta Vero 1-Handle Shower Only Faucet Trim Ki...
# 4           100005      17  Delta Vero 1-Handle Shower Only Faucet Trim Ki...
# 5           100006      18  Whirlpool 1.9 cu. ft. Over the Range Convectio...
# 6           100006      20  Whirlpool 1.9 cu. ft. Over the Range Convectio...
# 7           100006      21  Whirlpool 1.9 cu. ft. Over the Range Convectio...
# 8           100007      23  Lithonia Lighting Quantum 2-Light Black LED Em...
# 9           100009      27  House of Fara 3/4 in. x 3 in. x 8 ft. MDF Flut...
# 10          100010      34       Valley View Industries Metal Stakes (4-Pack)
# 11          100011      35  Toro Personal Pace Recycler 22 in. Variable Sp...
# 12          100011      37  Toro Personal Pace Recycler 22 in. Variable Sp...
# 13          100011      38  Toro Personal Pace Recycler 22 in. Variable Sp...
# 14          100012      48  Hampton Bay Caramel Simple Weave Bamboo Rollup...
# 15          100013      51  InSinkErator SinkTop Switch Single Outlet for ...
# 16          100016      65  Sunjoy Calais 8 ft. x 5 ft. x 8 ft. Steel Tile...
#
# 16                                   grill gazebo       3.00
# 17                                    door guards       1.00
# 18                         metal plate cover gcfi       1.67
# 19                                 radiator grate       2.33
# 20                                windows screens       2.33
# 21                       1x1 rail decorative wood       1.33
# 22                         4*8 beadboard paneling       2.67
# 23                               4x8wood paneling       2.33
# 24                                        MDF 4x8       1.33
# 25                            wainscot chair rail       2.33
# 26                        wainscot plank paneling       2.33
# 27                                 lawn sprkinler       2.00
# 28                             rainbird sprinkler       2.33
# 29                           PLATFORM FOR WASHERS       2.67
# ...                                           ...        ...
# 74037                plastic 3 piece nativity set       1.67
# 74038                  pass through curtain rings       1.33
# 74039                crosley lafayette kf30024bwh       2.33
# 74040                            dremel auto rust       2.33
# 74041                   privacy glass pivot doors       2.67
# 74042                alabaster blinds 39x72 alvin       1.67
# 74043       exterior shutter with movable louvers       3.00
# 74044                                 lightsensor       2.67
# 74045                      bypass 12 water filter       1.33
# 74046                                     ni-2.4v       2.00
# 74047                        hard hat with mining       1.67
# 74048    replace a broken glass in a vinyl window       2.00
# 74049                 ceiling fan with chain cord       1.00
# 74050                             florentine clay       2.33
# 74051                          trim a home lights       2.00
# 74052                     whitehaus bathroom sinl       2.33
# 74053                        6.5 hp gas generator       2.33
# 74054                      splash guard for  wall       2.00
# 74055                spicewood springs floor tile       1.67
# 74056                        laguna porcelin tile       2.00
# 74057                               m6 screw 90mm       2.67
# 74058                           sink tip-out tray       3.00
# 74059          fiberglass front doors by masonite       3.00
# 74060                          starter fertillzer       2.00
# 74061  rondec stainless steel 3/8 edge protection       3.00
# 74062                              tv riser glass       1.00
# 74063                           r20 halogen light       3.00
# 74064     schlage lock siena half dummy knob with       2.33
# 74065                           zen garden  decor       3.00
# 74066                fine sheer curtain 63 inches       2.33
#
#                                      product_description  \
# 0      Not only do angles make joints stronger, they ...
# 1      Not only do angles make joints stronger, they ...
# 2      BEHR Premium Textured DECKOVER is an innovativ...
# 3      Update your bathroom with the Delta Vero Singl...
# 4      Update your bathroom with the Delta Vero Singl...
# 5      Achieving delicious results is almost effortle...
# 6      Achieving delicious results is almost effortle...
# 7      Achieving delicious results is almost effortle...
# 8      The Quantum Adjustable 2-Light LED Black Emerg...
# 9      Get the House of Fara 3/4 in. x 3 in. x 8 ft. ...
# 10     Valley View Industries Metal Stakes (4-Pack) a...
# 11     Recycler 22 in. Personal Pace Variable Speed S...
# 12     Recycler 22 in. Personal Pace Variable Speed S...
# 13     Recycler 22 in. Personal Pace Variable Speed S...
# 14     The 96 in. wide Caramel Simple Weave Rollup Ba...
# 15     The InSinkErator SinkTop Switch Single Outlet ...
# 16     Make grilling great with this handsome and fun...
# 17     The MD Building Products 36 in. x 36 in. x 1/5...
# 18     The MD Building Products 36 in. x 36 in. x 1/5...
# 19     The MD Building Products 36 in. x 36 in. x 1/5...
# 20     The MD Building Products 36 in. x 36 in. x 1/5...
# 21     The House of Fara 8 Linear ft. primed MDF Over...
# 22     The House of Fara 8 Linear ft. primed MDF Over...
# 23     The House of Fara 8 Linear ft. primed MDF Over...
# 24     The House of Fara 8 Linear ft. primed MDF Over...
# 25     The House of Fara 8 Linear ft. primed MDF Over...
# 26     The House of Fara 8 Linear ft. primed MDF Over...
# 27     Installed in parks and backyards across the gl...
# 28     Installed in parks and backyards across the gl...
# 29     The Samsung 4.2 cu. ft. Front Load Washer with...
# ...                                                  ...
# 74037  Have the perfect trio of decorating bags with ...
# 74038  The Husky 126-Piece Pass-Through Socket and Ra...
# 74039  Enhance your living space with Crosley's impec...
# 74040  Rust-Oleum Automotive Touch-Up aerosols are id...
# 74041  Whether you are designing a new bathroom, or r...
# 74042  Bali Cut-to-Size Vertical Blinds offer beautif...
# 74043  Instantly add value and style to your home wit...
# 74044  This Newport Coastal Photo Eye Replacement con...
# 74045  If you already have an inline filter and want ...
# 74046  Flexibility at its best. The Worx 2-in-1 12 Gr...
# 74047  3M TEKK Protection Vented Pro Ratchet Hard Hat...
# 74048  Excellent privacy and decorative solution for ...
# 74049  This Westinghouse Lighting Oil Rubbed Bronze B...
# 74050  BEHR Premium Plus Zero VOC, Self-Priming Inter...
# 74051  Quarter round is typically placed in front of ...
# 74052  Beautify your bathroom or powder room with a W...
# 74053  The Champion Power Equipment 3 in. semi-trash ...
# 74054  The Everbilt 4 in. Wall Guard helps prevent da...
# 74055  This dal-tile villa valleta calais springs por...
# 74056  Stone Harbor 7-Piece Dining Set includes Large...
# 74057  Crown Bolt's metric socket cap screws are idea...
# 74058  Add a little luxury to otherwise wasted space ...
# 74059  Create an inviting, stylish entryway with the ...
# 74060  Lilly Miller UltraGreen Vitamin B-1 Plant Star...
# 74061  The EV/RO100E is a prefabricated corner for Ro...
# 74062  Atlantic, Inc. 94835722 Uniquely designed for ...
# 74063  Philips Energy Advantage lamps use less energy...
# 74064  The Schlage Camelot In-Active Aged Bronze Hand...
# 74065  The Rose Garden is inspired by the popular ear...
# 74066  No. 918 Millennial Ryan heathered texture semi...
#
#                              clean_terms  clean_length  title_length  \
# 0                          angle bracket           2.0           4.0
# 1                                bracket           1.0           4.0
# 2                                   deck           1.0          11.0
# 3                       rain shower head           3.0          13.0
# 4                          shower faucet           2.0          13.0
# 5                         convection otr           2.0          15.0
# 6                        microwave stove           2.0          15.0
# 7                             microwaves           1.0          15.0
# 8                        emergency light           2.0           9.0
# 9                                    mdf           1.0          14.0
# 10                          steele stake           2.0           6.0
# 11            briggs stratton lawn mower           4.0          17.0
# 12                              gas mowe           2.0          17.0
# 13                           honda mower           2.0          17.0
# 14       hampton bay chestnut pull shade           5.0          16.0
# 15                              disposer           1.0           8.0
# 16                          grill gazebo           2.0          15.0
# 17                           door guards           2.0          12.0
# 18                     metal plate cover           3.0          12.0
# 19                        radiator grate           2.0          12.0
# 20                       windows screens           2.0          12.0
# 21                  rail decorative wood           3.0          12.0
# 22                              paneling           1.0          12.0
# 23                              paneling           1.0          12.0
# 24                                   mdf           1.0          12.0
# 25                   wainscot chair rail           3.0          12.0
# 26               wainscot plank paneling           3.0          12.0
# 27                                  lawn           1.0          10.0
# 28                    rainbird sprinkler           2.0          10.0
# 29                      platform washers           2.0          13.0
# ...                                  ...           ...           ...
# 74037         plastic piece nativity set           4.0          11.0
# 74038                 pass curtain rings           3.0           7.0
# 74039                  crosley lafayette           2.0           8.0
# 74040                   dremel auto rust           3.0          10.0
# 74041          privacy glass pivot doors           4.0          21.0
# 74042             alabaster blinds alvin           3.0           9.0
# 74043   exterior shutter movable louvers           4.0          18.0
